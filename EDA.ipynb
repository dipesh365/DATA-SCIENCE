# %% [markdown]
# <a href="https://colab.research.google.com/github/dipesh365/DATA-SCIENCE/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **EDA**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/train.csv')

# %% [markdown]
# 1. How big is the data?

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# 2. How does the data look like?

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 24            25         0       3  Palsson, Miss. Torborg Danira  female
# 791          792         0       2            Gaskell, Mr. Alfred    male
# 22            23         1       3    McGowan, Miss. Anna "Annie"  female
# 521          522         0       3                Vovk, Mr. Janko    male
# 805          806         0       3      Johansson, Mr. Karl Johan    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 24    8.0      3      1  349909  21.0750   NaN        S
# 791  16.0      0      0  239865  26.0000   NaN        S
# 22   15.0      0      0  330923   8.0292   NaN        Q
# 521  22.0      0      0  349252   7.8958   NaN        S
# 805  31.0      0      0  347063   7.7750   NaN        S

# %% [markdown]
# 3. What is the data type of cols?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# 4. Are there any missing values?

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# 5. How does the data look mathematically?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# 6. Are there duplicate values?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 7. How is the correlation between cols?

# %%
df.select_dtypes(include=['number']).corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df.select_dtypes(include=['number']).corr()['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64

# %% [markdown]
# **UNIVARIANT ANALYSIS**

# %% [markdown]
# 1.   CATAGORICAL DATA
# 2.  COUNTPLOT

# %%
#sns.countplot(df['Pclass'])
df['Pclass'].value_counts().plot(kind='bar')
#
# Out:
# <Axes: xlabel='Pclass'>

# %% [markdown]
# piechart

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# *   NUMERICAL DATA
# *   HISTOGRAM

# %%
plt.hist(df['Age'],bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# DISPLOT

# %%
sns.displot(df['Age'])

# %% [markdown]
# BOXPLOT

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].min()
# Out:
# 0.42

# %% [markdown]
# **BIVARIATE AND MULTIVARIATEANALYSIS**

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic=sns.load_dataset('titanic')

# %%
flights=sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# SCCATTERPLOT(NUMERICAL-NUMERICAL)

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# multi with which are male and which are female

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips,hue='sex',style='smoker',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# BAR PLOT (NUMERICAL-CATAGORICAL)

# %%
sns.barplot(x='pclass',y='fare',hue='sex',data=titanic)
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %% [markdown]
# BOX PLOT(NUMERICAL-CATEGORICAL)

# %%
sns.boxplot(x='sex',y='age',hue='survived',data=titanic)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# DISTPLOT(NUMERICAL-CATEGORICAL)

# %%
sns.histplot(titanic['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.kdeplot(titanic[titanic['survived']==0]['age'])
sns.kdeplot(titanic[titanic['survived']==1]['age'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# HEATMAP (CATAGORICAL-CATAGORICAL)

# %%
pd.crosstab(titanic['pclass'],titanic['survived'])
# Out:
# survived    0    1
# pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(titanic['pclass'],titanic['survived']), annot=True, fmt='d', cmap='YlGnBu')
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>

# %%
titanic.groupby('sex')['survived'].mean()*100
# Out:
# sex
# female    74.203822
# male      18.890815
# Name: survived, dtype: float64

# %% [markdown]
# CLUSTER MAP(CATAGORICAL-CATAGORICAL)

# %%
sns.clustermap(pd.crosstab(titanic['sibsp'],titanic['survived']))

# %% [markdown]
# PAIRPLOT

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# LINEPLOT(NUM-NUM)(DATE,TIME,NUM)IN X

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
new=flights.groupby('year')['passengers'].sum().reset_index()

# %%
sns.lineplot(x='year', y='passengers', data=new)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# /tmp/ipykernel_3150/1868718285.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year'))

# %% [markdown]
# ** PANDAS PROFILILING**

# %%
import pandas as pd
df = pd.read_csv('/content/train.csv')

# %%
# !pip uninstall pandas-profiling -y
# !pip uninstall numba -y
# !pip install ydata-profiling
# Out:
# WARNING: Skipping pandas-profiling as it is not installed.
# Found existing installation: numba 0.60.0
# Uninstalling numba-0.60.0:
#   Successfully uninstalled numba-0.60.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.8/400.8 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 37.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 68.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 30.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
# ...

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# /tmp/ipykernel_3150/484759429.py:1: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from IPython.display import IFrame
IFrame(src='./output.html', width=900, height=600)
# Out:
#         <iframe
#             width="900"
#             height="600"
#             src="./output.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
