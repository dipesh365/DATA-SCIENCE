# %% [markdown]
# <a href="https://colab.research.google.com/github/dipesh365/DATA-SCIENCE/blob/main/API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **HOW TO WORK WITH API**

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/zMwhWailP1WY7sb6AoE6b8ugoy.jpg',
#   'genre_ids': [12, 16, 10751, 14],
#   'id': 1007757,
#   'title': 'Swapped',
#   'original_language': 'en',
#   'original_title': 'Swapped',
#   'overview': 'A small woodland creature and a majestic bird, two natural sworn enemies of the Valley, magically trade places and set off on an adventure of a lifetime to switch back. Their journey soon uncovers a greater threat—one that could endanger not only their species, but the entire valley they call home.',
#   'popularity': 324.1286,
#   'poster_path': '/tHhxWxge06goXU6ZQH1hj7vK8Hd.jpg',
#   'release_date': '2026-05-01',
#   'softcore': False,
#   'video': False,
#   'vote_average': 8.978,
#   'vote_count': 1252},
#  {'adult': False,
#   'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'title': 'The Shawshank Redemption',
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
# ...

# %%
tdf = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
tdf.head()
# Out:
#         id                        title  \
# 0  1007757                      Swapped
# 1      278     The Shawshank Redemption
# 2      238                The Godfather
# 3   687163            Project Hail Mary
# 4  1330021  Remarkably Bright Creatures
#
#                                             overview release_date  popularity  \
# 0  A small woodland creature and a majestic bird,...   2026-05-01    324.1286
# 1  Imprisoned in the 1940s for the double murder ...   1994-09-23     58.7166
# 2  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     47.1045
# 3  Science teacher Ryland Grace wakes up on a spa...   2026-03-15    402.3877
# 4  Through unlikely bonds formed during night shi...   2026-05-07    106.2885
#
#    vote_average  vote_count
# 0         8.978        1252
# 1         8.721       30376
# 2         8.686       22919
# 3         8.610        3798
# 4         8.576         355

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#            id                        title  \
# 0     1007757                      Swapped
# 1         278     The Shawshank Redemption
# 2         238                The Godfather
# 3      687163            Project Hail Mary
# 4     1330021  Remarkably Bright Creatures
# ...       ...                          ...
# 8555   308453                   The Bronze
# 8556   366514                  Up for Love
# 8557   242095                   The Signal
# 8558      818  Austin Powers in Goldmember
# 8559   269795                         2:22
#
#                                                overview release_date  \
# 0     A small woodland creature and a majestic bird,...   2026-05-01
# 1     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 2     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 3     Science teacher Ryland Grace wakes up on a spa...   2026-03-15
# 4     Through unlikely bonds formed during night shi...   2026-05-07
# ...

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movie.csv')

# %%
import requests

url = "https://twitter-api45.p.rapidapi.com/community_info.php"

querystring = {"community_id":"1493290339532222469"}

headers = {
	"x-rapidapi-key": "7cc1b5f861mshba9f3b67bb44b12p14d717jsn6a32a5c024c5",
	"x-rapidapi-host": "twitter-api45.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'message': 'You are not subscribed to this API.'}
